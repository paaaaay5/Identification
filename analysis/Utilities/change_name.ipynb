# %%
import glob
import os

path="/Project/Data/HOKKAIDO/camera34/*.csv"

flist=glob.glob(path)

# %%
store_path="/Project/Data/HOKKAIDO/camera"

for file in flist:
     a=file[37:]
     num=a[0:-4]


     if len(num) == 1:
          num="00"+num
     if len(num) == 2:
          num="0"+num
     os.rename(file,store_path+"/"+"Cow"+num+".csv")

# %%
a=file[37:]
a[0:-4]
# Out:
# '1'

# %%
for file in flist:  

    if len(num) == 1:
        num="00"+num
    if len(num) == 2:
        num="0"+num
    print(num)
# Out:
# 001
# 010
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 011
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 012
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 013
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 014
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 015
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 016
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 017
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 018
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 019
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 002
# 020
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 021
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 022
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 023
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 024
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# ...

# %%
# Out:
# '10.csv'
