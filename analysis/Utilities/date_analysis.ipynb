# %%
import numpy as np
import pandas as pd
import datetime

# %%
path="G:\\identification\\Data\\DATA5\\3D_TRAIN_DATA"
path2="G:\\identification\\Data\\DATA4\\cow_300"

# %%
import os
lis=os.listdir(path)
lis2=os.listdir(path)

# %%
for i in range(len(lis)):
    path3=path2+"\\"+str(lis2[i])
    lis3=os.listdir(path3)
    year=[]
    mon=[]

    for j in range(len(lis3)):
        name=lis3[j]
        year.append(name[0:4])
        mon.append(name[4:6])

    ran_y=int(year[-1]) - int(year[0])
    ran_m=12 + int(mon[-1]) - int(mon[0])
    if ran_m >=12:
        ran_m-=12
        ran_y+=1

    print(ran_y)
    print(ran_m)
    print("-------")
# Out:
# 2
# 10
# -------
# 1
# 10
# -------
# 2
# 0
# -------
# 2
# 1
# -------
# 2
# 10
# -------
# 2
# 4
# -------
# 2
# 10
# -------
# 2
# 8
# -------
# 2
# 10
# -------
# 2
# 8
# -------
# 2
# 4
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 1
# -------
# 2
# 10
# -------
# 2
# 1
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 11
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 8
# -------
# 2
# 10
# -------
# 2
# 5
# -------
# 2
# 8
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 8
# -------
# 2
# 10
# -------
# 2
# 9
# -------
# 2
# 10
# -------
# 2
# 10
# -------
# 2
# 7
# -------
# 2
# 4
# -------
# 2
# 5
# -------
# 2
# 3
# -------
# 2
# 3
# -------
# 2
# 6
# -------
# 2
# 5
# -------
# 2
# 1
# -------
# 2
# 7
# -------
# 2
# 5
# -------
# 2
# 5
# -------
# 2
# 7
# -------
# 2
# 7
# -------
# 2
# 5
# -------

# %%
0.1*float(ran_m) +ran_y
# Out:
# 2.5
